# %%
import os
os.chdir("C:/Users/Administrator/PythonProjects/abfluss_queich")

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from database.queries import load_discharge_data, load_inference_data, load_precip_observation_data, load_precip_forecast_data

# %%
df_discharge_csv = pd.read_csv(
    "data/discharge_siebeldingen_2026-0514.csv",
    decimal=",", 
    sep=";", 
    na_values="-"
    )

df_discharge_csv = df_discharge_csv.set_index("timestamp")

# %%
df_discharge = load_discharge_data(days=30)
df_precip_observation = load_precip_observation_data(days=30)
df_precip_forecast = load_precip_forecast_data(days=30)

# %%
fig, axs = plt.subplots(figsize = (10,8), nrows=4, sharex=True)

axs[0].plot(df_discharge_csv)
axs[1].plot(df_discharge)
axs[2].plot(df_precip_observation, alpha=0.5)
axs[2].plot(df_precip_forecast[df_precip_forecast >= 0], color="red", alpha=0.5)
axs[3].plot(df_precip_forecast[df_precip_forecast >= 0], color="red")

plt.show()
# Out:
# 2026-05-25 19:08:43,693 | category.py | INFO | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-05-25 19:08:44,329 | category.py | INFO | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 fig, axs = plt.subplots(figsize = (10,8), nrows=4, sharex=True)
#       3 axs[1].plot(df_discharge_csv)
# ----> 4 axs[0].plot(df_discharge)
#       5 axs[2].plot(df_precip_observation, alpha=0.5)
#       6 axs[2].plot(df_precip_forecast[df_precip_forecast >= 0], color="red", alpha=0.5)
#
# ...
