# %%
import requests

# url = "https://www.hochwasser.rlp.de/api/v1/measurement-site/23770507"
url = "https://geodaten-wasser.rlp-umwelt.de/api/data/messstellen_wasserstand_abflusswerte_30?w=messstellennummer=2377050700"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 Chrome/137 Safari/537.36"
    ),
    "Referer": "https://geodaten-wasser.rlp-umwelt.de/",
}

r = requests.get(url, headers=headers)

# %%
print(r.status_code)
print(r.text[:200])
# Out:
# 200
# [{"messstellennummer":2377050700,"messstellenbezeichnung":"Siebeldingen","datestring":"2026-05-15T18:45:00.000+00:00","datum":"15.05.2026 20:45","cleardate":"15.05.2026","time":"20:45","abfluss":"

# %%
import pandas as pd
import requests

URL = (
    "https://www.hochwasser.rlp.de/"
    "flussgebiet/oberrhein/siebeldingen#abfluesse"
)

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
    )
}

# tables = pd.read_html(
tables = requests.get(URL, headers=headers).text
# )
print(tables)

# print(f"{len(tables)=}")

# df = tables[0]
# print(df.head())
# Out:
# <!doctype html><html lang="de"><head><meta charset="utf-8"/><link rel="icon" href="/favicon.ico"/><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon-180x180.png"/><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png"/><link rel="manifest" href="/manifest.json"/><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0"/><meta name="theme-color" content="#000000"/><meta name="description" content="Hochwasservorhersagezentrale Rheinland-Pfalz"/><meta name="author" content="Landesamt fÃ¼r Umwelt, Wasserwirtschaft und Gewerbeaufsicht Rheinland-Pfalz"/><link rel="manifest" href="/manifest.json"/><title>Hochwasservorhersagezentrale Rheinland-Pfalz</title><script>function setViewportProperty(e){var t;function n(){var n=e.clientHeight;n!==t&&requestAnimationFrame((function(){e.style.setProperty("--vh",.009999*n+"px"),t=n}))}return n(),n}wind
# ...
